# %%
import numpy as np
import pandas as pd

# %%
# Creating a DataFrame
data = {
    "Product": ["Laptop", "Phone", "Headphones", "Keyboard", "Monitor"],
    "Price": [1000, 700, 150, 80, 300]
}


df1 = pd.DataFrame(data)

print(df)

df1.to_csv("products.csv", index=False)
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Total_marks
# 0           263
# 1           240
# 2           277
# 3           263
# 4           262
# 5           236
# 6           273
# 9           281
# 10          240

# %%
df1['Discount_price']=df['Price']*.90
save_pth='/content/drive/MyDrive/Colab Notebooks/Phitron  AI ML/PYTHON/Week 4/Module-15.5/Discount_price.csv'
df1.to_csv(save_pth,index=False)
print(save_pth)
df1
# Out:
# /content/drive/MyDrive/Colab Notebooks/Phitron  AI ML/PYTHON/Week 4/Module-15.5/Discount_price.csv
#       Product  Price  Discount_price
# 0      Laptop   1000          1080.0
# 1       Phone    700          1350.0
# 2  Headphones    150           990.0
# 3    Keyboard     80          1080.0
# 4     Monitor    300          2250.0

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Phitron  AI ML/PYTHON/Week 4/Module-15.5/Practice Day (1).csv')
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80

# %%
dplct_cnt=df.duplicated(subset='EmployeeID').sum()
cln_df=df.drop_duplicates(subset='EmployeeID',keep='first')
cln_df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94

# %%
ms_age=df['Age'].isnull().sum()
ms_sal=df['Salary'].isnull().sum()
print(ms_age,ms_sal)
mn_age=df['Age'].mean()
df['Age'].fillna(mn_age,inplace=True)
df_cln=df.dropna(subset='Salary')
df_cln
# Out:
# 0 0
# /tmp/ipython-input-2009845443.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(mn_age,inplace=True)
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# ...

# %%
mn_marks1=df['Marks1'].mean()
mn_marks2=df['Marks2'].mean()
mn_marks3=df['Marks3'].mean()
print(mn_marks1,mn_marks2,mn_marks3)
mx_marks1=df['Marks1'].max()
mx_marks2=df['Marks2'].max()
mx_marks3=df['Marks3'].max()
print(mx_marks1,mx_marks2,mx_marks3)
df['Total_marks']=df['Marks1']+df['Marks2']+df['Marks3']
print(df['Total_marks'])
total_std=df['Total_marks'].std()
print(total_std)
df
# Out:
# 85.22222222222223 87.33333333333333 86.88888888888889
# 95 95 94
# 0     263
# 1     240
# 2     277
# 3     263
# 4     262
# 5     236
# 6     273
# 9     281
# 10    240
# Name: Total_marks, dtype: int64
# 16.934514394507385
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.hist(df['Age'],bins=10,color='red',edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Age'],df['Salary'],color='green',marker='o')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs Salary')
# Out:
# Text(0.5, 1.0, 'Age vs Salary')

# %%
plt.figure(figsize=(10,6))
plt.scatter(df1['Price'],df1['Discount_price'],color='green',marker='o')
plt.xlabel('Price')
plt.ylabel('Discount_price')
plt.title('Price vs Discount_price')
# Out:
# Text(0.5, 1.0, 'Price vs Discount_price')
